# %% [markdown]
# # Mini-Project: Gene Information Card
# # Choose YOUR favorite gene and create an info card!

# %%
gene = "TP53"                                   # Change this to your gene
full_name = "Tumor Protein p53"                 # Change this
chromosome = 17                                 # Change this
role = "tumor suppressor - prevents cancer"    # Change this
discovery_year = 1979                          # Add this info!
protein_length = 393                           # Add this info!

# %%
# Create a nice display
print("=" * 50)
print("GENE INFORMATION CARD")
print("=" * 50)
print("Gene Symbol:",gene)
print("Full Name:", full_name)
print("Chromosome:", chromosome)
print("Role:", role)
print("Discovered:", discovery_year)
print("Protein Length:", protein_length, "amino acids")
print("=" * 50)
# Out:
# ...
# GENE INFORMATION CARD
# ...
# Gene Symbol: TP53
# Full Name: Tumor Protein p53
# Chromosome: 17
# Role: tumor suppressor - prevents cancer
# Discovered: 1979
# Protein Length: 393 amino acids
# ...
