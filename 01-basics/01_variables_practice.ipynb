# %% [markdown]
# # Exercise 1: Store Gene Information
# # Store information about the BRCA1 gene
# # Gene name: BRCA1
# # Chromosome: 17
# # Associated with: Breast cancer
# # Discovery year: 1994

# %%
gene_name = "BRCA1"
chromosome = 17
associated_with = "Breast cancer"
discovery_year = 1994


print("Gene:", gene_name)
print("Chromosome:", chromosome)
print("Disease:", associated_with)
print("Discovered:", discovery_year)
# Out:
# Gene: BRCA1
# Chromosome: 17
# Disease: Breast cancer
# Discovered: 1994

# %% [markdown]
# # Exercise 2: DNA Sequence Storage
# # Store a DNA sequence and analyze it

# %%
sequence = "ATGCGATCGATCG"
print("Length:", len(sequence), "base pairs")
# Out:
# Length: 13 base pairs

# %% [markdown]
# # Exercise 3: Patient Sample Info
# # Create variables for a patient sample

# %%
sample_id = "S001"
patient_age = 45
tumor_type = "adenocarcinoma"
sample_date = "2026-05-05"




print("=" * 40)
print("PATIENT SAMPLE REPORT")
print("=" * 40)
print("Sample Id:", sample_id)
print("Patient Age:", patient_age)
print("Tumor Type:", tumor_type)
print("Collection Date:", sample_date)
print("=" * 40)
# Out:
# ...
# PATIENT SAMPLE REPORT
# ...
# Sample Id: S001
# Patient Age: 45
# Tumor Type: adenocarcinoma
# Collection Date: 2026-05-05
# ...

# %% [markdown]
# # Exercise 4: Calculate Gene Length
# # Calculate the length of a gene from coordinates

# %%
start = 43044295
end = 43125483

# Calculate length
gene_length = end - start

print("Start Position:", start)
print("End Position:", end)
print("Gene Length:", gene_length, "base pairs")
# Out:
# Start Position: 43044295
# End Position: 43125483
# Gene Length: 81188 base pairs

# %% [markdown]
# # Exercise 5: Multiple Sequences
# # Store and display multiple DNA sequences

# %%
seq1 = "ATGC"
seq2 = "GCTA"
seq3 = "TACG"

print("Sequence 1:", seq1)
print("Sequence 2:", seq2)
print("Sequence 3:", seq3)

# printing lengths
print("Seq 1:", len(seq1), "bp")
print("Seq 2:", len(seq2),"bp")
print("Seq 3:", len(seq3),"bp")
# Out:
# Sequence 1: ATGC
# Sequence 2: GCTA
# Sequence 3: TACG
# Seq 1: 4 bp
# Seq 2: 4 bp
# Seq 3: 4 bp
